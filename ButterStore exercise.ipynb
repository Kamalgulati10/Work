# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(0)
butter_sales=np.random.randint(0,50,(5,3))

# %%
butter_sales
# Out:
# array([[44, 47,  0],
#        [ 3,  3, 39],
#        [ 9, 19, 21],
#        [36, 23,  6],
#        [24, 24, 12]])

# %%
weekly_sales=pd.DataFrame(butter_sales,
                          index=["Mon","Tue","Wed","Thur","Fri"],
                          columns=["Almond Butter","Peanut Butter","Cashew Butter"])

# %%
weekly_sales
# Out:
#       Almond Butter  Peanut Butter  Cashew Butter
# Mon              44             47              0
# Tue               3              3             39
# Wed               9             19             21
# Thur             36             23              6
# Fri              24             24             12

# %%
prices=np.array([10,8,12])

# %%
prices
# Out:
# array([10,  8, 12])

# %%
weekly_sales["Almond Butter"]
# Out:
# Mon     44
# Tue      3
# Wed      9
# Thur    36
# Fri     24
# Name: Almond Butter, dtype: int32

# %%
array_1=np.array(weekly_sales["Almond Butter"])
array_2=np.array(weekly_sales["Peanut Butter"])
array_3=np.array(weekly_sales["Cashew Butter"])

# %%
array_4=np.array([array_1,array_2,array_3])

# %%
array_4
# Out:
# array([[44,  3,  9, 36, 24],
#        [47,  3, 19, 23, 24],
#        [ 0, 39, 21,  6, 12]])

# %%
array_4=array_4.T

# %%
array_4
# Out:
# array([[44, 47,  0],
#        [ 3,  3, 39],
#        [ 9, 19, 21],
#        [36, 23,  6],
#        [24, 24, 12]])

# %%
array_4.shape
# Out:
# (5, 3)

# %%
prices.shape
# Out:
# (3,)

# %%
x=np.dot(prices,array_4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-66abf903baae> in <module>
# ----> 1 x=np.dot(prices,array_4)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (3,) and (5,3) not aligned: 3 (dim 0) != 5 (dim 0)

# %%
array_4.shape
# Out:
# (5, 3)

# %%
prices.shape
# Out:
# (3,)

# %%
prices=prices.reshape(1,3)

# %%
prices.shape
# Out:
# (1, 3)

# %%
array_4.shape
# Out:
# (5, 3)

# %%
total_prices=prices.dot(array_4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-79d1837e2aa0> in <module>
# ----> 1 total_prices=prices.dot(array_4)
#
# ValueError: shapes (1,3) and (5,3) not aligned: 3 (dim 1) != 5 (dim 0)

# %%
total_prices=np.dot(prices,array_4.T)

# %%
total_prices
# Out:
# array([[816, 522, 494, 616, 576]])

# %%
weekly_sales
# Out:
#       Almond Butter  Peanut Butter  Cashew Butter
# Mon              44             47              0
# Tue               3              3             39
# Wed               9             19             21
# Thur             36             23              6
# Fri              24             24             12

# %%
weekly_sales["Prices in $"]=total_prices.T

# %%
weekly_sales
# Out:
#       Almond Butter  Peanut Butter  Cashew Butter  Prices in $
# Mon              44             47              0          816
# Tue               3              3             39          522
# Wed               9             19             21          494
# Thur             36             23              6          616
# Fri              24             24             12          576
